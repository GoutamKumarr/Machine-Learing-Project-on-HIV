# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier,AdaBoostClassifier,BaggingClassifier,GradientBoostingClassifier
import xgboost as xgb
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import plotly.express as px
#       4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
#
# ModuleNotFoundError: No module named 'plotly'

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install plotly.express
# Out:
# ...
#      ---------------------------------------- 0.0/15.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/15.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/15.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/15.3 MB ? eta -:--:--
#      --------------------------------------- 0.0/15.3 MB 178.6 kB/s eta 0:01:26
#      --------------------------------------- 0.0/15.3 MB 178.6 kB/s eta 0:01:26
#      --------------------------------------- 0.0/15.3 MB 178.6 kB/s eta 0:01:26
#      --------------------------------------- 0.1/15.3 MB 182.2 kB/s eta 0:01:24
#      --------------------------------------- 0.1/15.3 MB 285.2 kB/s eta 0:00:54
#      --------------------------------------- 0.1/15.3 MB 285.2 kB/s eta 0:00:54
#      --------------------------------------- 0.1/15.3 MB 285.2 kB/s eta 0:00:54
#       -------------------------------------- 0.2/15.3 MB 444.3 kB/s eta 0:00:35
# ...

# %%
pip install matplotlib.pyplot
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/293.3 kB ? eta -:--:--
#      - -------------------------------------- 10.2/293.3 kB ? eta -:--:--
#      - -------------------------------------- 10.2/293.3 kB ? eta -:--:--
#      - -------------------------------------- 10.2/293.3 kB ? eta -:--:--
#      ----- ------------------------------- 41.0/293.3 kB 196.9 kB/s eta 0:00:02
#      ----- ------------------------------- 41.0/293.3 kB 196.9 kB/s eta 0:00:02
#      ---------- -------------------------- 81.9/293.3 kB 286.7 kB/s eta 0:00:01
#      ------------- ---------------------- 112.6/293.3 kB 328.2 kB/s eta 0:00:01
#      ------------- ---------------------- 112.6/293.3 kB 328.2 kB/s eta 0:00:01
#      ----------------------- ------------ 194.6/293.3 kB 436.8 kB/s eta 0:00:01
#      ------------------------------ ----- 245.8/293.3 kB 519.9 kB/s eta 0:00:01
#      ------------------------------ ----- 245.8/293.3 kB 519.9 kB/s eta 0:00:01
# ...

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier,AdaBoostClassifier,BaggingClassifier,GradientBoostingClassifier
import xgboost as xgb
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [8], in <cell line: 6>()
#       4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
# ----> 6 from sklearn.ensemble import VotingClassifier
#       7 from sklearn.linear_model import LogisticRegression
#       8 from sklearn.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
dataset=('https://www.kaggle.com/datasets/programmerrdai/hiv-aids')

# %%
pip install opendatasets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import opendatasets as od

# %%
dataset=('https://www.kaggle.com/datasets/programmerrdai/hiv-aids')

# %%
od.download(dataset)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: goutamkumar03
# Your Kaggle Key: ········
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 2.84M/2.84M [00:01<00:00, 1.68MB/s]

# %%
import os

# %%
data_dir='.\hiv-aids'

# %%
os.listdir(data_dir)
# Out:
# ['annual-number-of-deaths-by-cause.csv',
#  'antiretroviral-therapy-coverage-among-people-living-with-hiv.csv',
#  'art-coverage-for-pregnant-women.csv',
#  'children-living-with-hiv.csv',
#  'condom-use-at-last-high-risk-sex.csv',
#  'condom-use-during-last-high-risk-sex.csv',
#  'deaths-and-new-cases-of-hiv.csv',
#  'deaths-from-hiv-by-age.csv',
#  'hiv-death-rates-by-age.csv',
#  'hiv-death-rates.csv',
#  'hiv-expenditure.csv',
#  'hiv-funding-and-future-requirements.csv',
#  'hivaids-deaths-and-averted-due-to-art.csv',
#  'knowledge-hiv-prevention-in-males-vs-females.csv',
#  'life-expectancy.csv',
#  'new-cases-of-hiv-infection.csv',
#  'new-cases-of-hiv-unaids-vs-ihme.csv',
#  'number-of-children-newly-infected-with-hiv.csv',
#  'number-of-children-orphaned-from-aids.csv',
#  'number-of-deaths-by-risk-factor.csv',
#  'number-of-new-hiv-child-infections-vs-number-of-infections-averted-due-to-pmtct.csv',
#  'resource-needs-to-meet-hiv-targets.csv',
# ...

# %%
life_df= pd.read_csv('annual-number-of-deaths-by-cause.csv')

# %%
df = pd.read_csv('annual-number-of-deaths-by-cause.csv')
df.shape
df.head(10)
# Out:
#         Entity Code  Year Number of executions (Amnesty International)
# 0  Afghanistan  AFG  2007                                           15  \
# 1  Afghanistan  AFG  2008                                           17
# 2  Afghanistan  AFG  2009                                            0
# 3  Afghanistan  AFG  2011                                            2
# 4  Afghanistan  AFG  2012                                           14
# 5  Afghanistan  AFG  2013                                            2
# 6  Afghanistan  AFG  2014                                            6
# 7  Afghanistan  AFG  2015                                            1
# 8  Afghanistan  AFG  2016                                            6
# 9  Afghanistan  AFG  1990                                          NaN
#
#    Deaths - Meningitis - Sex: Both - Age: All Ages (Number)
# 0                                             2933.0         \
# 1                                             2731.0
# ...

# %%
df.describe()
# Out:
#               Year  Deaths - Meningitis - Sex: Both - Age: All Ages (Number)
# count  7273.000000                                        6840.000000         \
# mean   2004.425134                                        8213.149415
# std       8.623572                                       34982.934459
# min    1990.000000                                           0.000000
# 25%    1997.000000                                          19.000000
# 50%    2004.000000                                         150.500000
# 75%    2012.000000                                        1622.250000
# max    2019.000000                                      432524.000000
#
#        Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)
# count                                       6.840000e+03                                      \
# mean                                        2.736319e+04
# std                                         1.113146e+05
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7273 entries, 0 to 7272
# Data columns (total 36 columns):
#  #   Column                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                    --------------  -----
#  0   Entity                                                                                    7273 non-null   object
#  1   Code                                                                                      6206 non-null   object
#  2   Year                                                                                      7273 non-null   int64
#  3   Number of executions (Amnesty International)                                              267 non-null    object
#  4   Deaths - Meningitis - Sex: Both - Age: All Ages (Number)                                  6840 non-null   float64
# ...

# %%
df['Code'].value_counts()
# Out:
# Code
# AFG    30
# LCA    30
# NER    30
# NGA    30
# NIU    30
#        ..
# GUF     2
# WLF     1
# GLP     1
# NCL     1
# PYF     1
# Name: count, Length: 217, dtype: int64

# %%
df_ind = df [df['Entity'] == 'India']

# %%
df['Code'].value_counts()
# Out:
# Code
# AFG    30
# LCA    30
# NER    30
# NGA    30
# NIU    30
#        ..
# GUF     2
# WLF     1
# GLP     1
# NCL     1
# PYF     1
# Name: count, Length: 217, dtype: int64

# %%
df_ind.head(10)
# Out:
#      Entity Code  Year Number of executions (Amnesty International)
# 2819  India  IND  2007                                            0  \
# 2820  India  IND  2008                                            0
# 2821  India  IND  2009                                            0
# 2822  India  IND  2012                                            1
# 2823  India  IND  2013                                            1
# 2824  India  IND  2015                                            1
# 2825  India  IND  1990                                          NaN
# 2826  India  IND  1991                                          NaN
# 2827  India  IND  1992                                          NaN
# 2828  India  IND  1993                                          NaN
#
#       Deaths - Meningitis - Sex: Both - Age: All Ages (Number)
# 2819                                            62224.0         \
# 2820                                            60843.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
df_ind.set_index('Year').plot(figsize = (16,10))
# Out:
# <Axes: xlabel='Year'>

# %%
def code_rate(code_name):
    df_code = df [df['Entity'] == code_name]
    df_code.head(5)
    return df_code.set_index('Year').plot(figsize = (16,10))

code_rate('Ghana')
# Out:
# <Axes: xlabel='Year'>

# %%
df_comp = pd.read_csv('annual-number-of-deaths-by-cause.csv')
df_comp.shape
df_comp.head(10)
# Out:
#         Entity Code  Year Number of executions (Amnesty International)
# 0  Afghanistan  AFG  2007                                           15  \
# 1  Afghanistan  AFG  2008                                           17
# 2  Afghanistan  AFG  2009                                            0
# 3  Afghanistan  AFG  2011                                            2
# 4  Afghanistan  AFG  2012                                           14
# 5  Afghanistan  AFG  2013                                            2
# 6  Afghanistan  AFG  2014                                            6
# 7  Afghanistan  AFG  2015                                            1
# 8  Afghanistan  AFG  2016                                            6
# 9  Afghanistan  AFG  1990                                          NaN
#
#    Deaths - Meningitis - Sex: Both - Age: All Ages (Number)
# 0                                             2933.0         \
# 1                                             2731.0
# ...

# %%
df_1990_2020 = df_comp[(df_comp['Year'] >= 1990) & (df_comp['Year'] <= 2020) ]
df_1990_2020
# Out:
#            Entity Code  Year Number of executions (Amnesty International)
# 0     Afghanistan  AFG  2007                                           15  \
# 1     Afghanistan  AFG  2008                                           17
# 2     Afghanistan  AFG  2009                                            0
# 3     Afghanistan  AFG  2011                                            2
# 4     Afghanistan  AFG  2012                                           14
# ...           ...  ...   ...                                          ...
# 7268     Zimbabwe  ZWE  2015                                          NaN
# 7269     Zimbabwe  ZWE  2016                                          NaN
# 7270     Zimbabwe  ZWE  2017                                          NaN
# 7271     Zimbabwe  ZWE  2018                                          NaN
# 7272     Zimbabwe  ZWE  2019                                          NaN
#
#       Deaths - Meningitis - Sex: Both - Age: All Ages (Number)
# ...

# %%
df_1990_2020.isna().sum()
# Out:
# Entity                                                                                         0
# Code                                                                                        1067
# Year                                                                                           0
# Number of executions (Amnesty International)                                                7006
# Deaths - Meningitis - Sex: Both - Age: All Ages (Number)                                     433
# Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)        433
# Deaths - Parkinson's disease - Sex: Both - Age: All Ages (Number)                            433
# Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)                       433
# Deaths - Malaria - Sex: Both - Age: All Ages (Number)                                        433
# Deaths - Drowning - Sex: Both - Age: All Ages (Number)                                       433
# ...

# %%
df_exp_na = df_exp[df_exp.isna().any(axis = 1)]
df_exp_na
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [71], in <cell line: 1>()
# ----> 1 df_exp_na = df_exp[df_exp.isna().any(axis = 1)]
#       2 df_exp_na
#
# NameError: name 'df_exp' is not defined
